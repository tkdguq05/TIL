# %% [markdown]
# ### 큰 수 만들기
# __문제 설명__
# ```
# 어떤 숫자에서 k개의 수를 제거했을 때 얻을 수 있는 가장 큰 숫자를 구하려 합니다.
#
# 예를 들어, 숫자 1924에서 수 두 개를 제거하면 [19, 12, 14, 92, 94, 24] 를 만들 수 있습니다. 이 중 가장 큰 숫자는 94 입니다.
#
# 문자열 형식으로 숫자 number와 제거할 수의 개수 k가 solution 함수의 매개변수로 주어집니다. number에서 k 개의 수를 제거했을 때 만들 수 있는 수 중 가장 큰 숫자를 문자열 형태로 return 하도록 solution 함수를 완성하세요.
# ```
# __제한 조건__
# ```
# number는 1자리 이상, 1,000,000자리 이하인 숫자입니다.
# k는 1 이상 number의 자릿수 미만인 자연수입니다.
# ```

# %%
number	k	return
1924	2	94
1231234	3	3234
4177252841	4	775841

# %%
list(map(str, [numbers]))
# Out:
# ['1231234']

# %%
numbers = "1924"
k=2

# %%
numbers = "1231234"
k = 3

# %%
str(max_num)
# Out:
# '3'

# %%
max(str(numbers))
# Out:
# '4'

# %%
str(numbers).index(max(str(numbers)))
# Out:
# 6

# %%
max_index
# Out:
# 1

# %%
number = 1231234
k = 3

# %%
def solution(number, k):
    stack = [number[0]]
    for num in number[1:]:
        while len(stack) > 0 and stack[-1] < num and k > 0:
            k -= 1
            print(stack, num,number)
            stack.pop()
        stack.append(num)
        print(stack)
    if k != 0:
        print('stack')
        stack = stack[:-k]
    return ''.join(stack)


solution('1231234', 3)
# Out:
# ['1'] 2 1231234
# ['2']
# ['2'] 3 1231234
# ['3']
# ['3', '1']
# ['3', '1'] 2 1231234
# ['3', '2']
# ['3', '2', '3']
# ['3', '2', '3', '4']
# '3234'

# %%
def solution(number, k):
    """
    스택을 이용해서 푼다. 키 포인트는 마지막에 스택에 남아있는 원소들을 넣은 순서대로 다시 뽑아야 한다는 것(즉 마지막에는 큐로써 동작해야 한다.)
    """
    from _functools import reduce

    n = len(number)
    st = []

    for elem in number:

        while st and k > 0:
            p = st[-1]

            if p >= elem:
                break

            st.pop()
            k -= 1

        st.append(elem)

    while k > 0:
        st.pop()
        k-=1

    answer = reduce(lambda x,y: x+y, st)
    return answer

# %%
solution(numbers, k)
# Out:
# ['1'] 2
# ['2'] 3
# ['3', '1'] 2
# '3234'

# %%
numbers=31234
k=3
print('else')
k=k-1
while k != 0:

    rest_numbers = str(numbers)[max_index:]
    print(rest_numbers)
    min_num = min(rest_numbers)
    min_num_index = rest_numbers.index(min_num)
    print(min_num_index)
    rest_numbers = rest_numbers[:min_num_index] + rest_numbers[min_num_index+1:]
    print(rest_numbers)
    #return str(rest_numbers)
    k-=1
# Out:
# else
# 4
# 0
#
# 4
# 0

# %%
print(str(numbers).index(max_num))
max_num = max(str(numbers))
max_index = str(numbers).index(max(str(numbers)))
if str(numbers).index(max_num) < k :
    print('hh')
    max_num = str(int(max_num)-1)
    

    other_k = str(numbers).index(str(max_num))
    k = k-other_k
    numbers = str(numbers)[other_k:]
    print(max_num,numbers)
#     print(rest_numbers)
#     min_num = min(rest_numbers)
#     min_num_index = rest_numbers.index(min_num)

#     rest_numbers = rest_numbers[:min_num_index] + rest_numbers[min_num_index+1:]
#     print(k,rest_numbers)

else:
    print('else')
    k=k-1
    while k != 0:

        rest_numbers = str(numbers)[max_index:]
        min_num = min(rest_numbers)
        min_num_index = rest_numbers.index(min_num)

        rest_numbers = rest_numbers[:min_num_index] + rest_numbers[min_num_index+1:]
        print(rest_numbers)
        #return str(rest_numbers)
        k-=1
# Out:
# 4
# else
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-124-51872ba2d761> in <module>()
#      28
#      29         rest_numbers = rest_numbers[:min_num_index] + rest_numbers[min_num_index+1:]
# ---> 30         print(rest_numbers)
#      31         #return str(rest_numbers)
#      32         k-=1
#
# ~/anaconda/lib/python3.6/site-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# ~/anaconda/lib/python3.6/site-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
# ...

# %%
def solution(numbers, k):
    other_k = 0
    while
    
    
    #제일 큰 수 앞에 있는 숫자는 다 지운다.
    # 그런데 앞에 있는 갯수가 k개를 초과한다면 그 다음 작은 수를 찾는다.
    # 그다음에는 작은 숫자들을 지워준다.
    answer = 
    return answer
