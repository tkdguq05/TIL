# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame({
    '고객번호': [1001, 1002, 1003, 1004, 1005, 1006, 1007],
    '이름': ['둘리', '도우너', '또치', '길동', '희동', '마이콜', '영희']
}, columns=['고객번호', '이름'])
df1
# Out:
#    고객번호   이름
# 0  1001   둘리
# 1  1002  도우너
# 2  1003   또치
# 3  1004   길동
# 4  1005   희동
# 5  1006  마이콜
# 6  1007   영희

# %%
df2 = pd.DataFrame({
    '고객번호': [1001, 1001, 1005, 1006, 1008, 1001],
    '금액': [10000, 20000, 15000, 5000, 100000, 30000]
}, columns=['고객번호', '금액'])
df2
# Out:
#    고객번호      금액
# 0  1001   10000
# 1  1001   20000
# 2  1005   15000
# 3  1006    5000
# 4  1008  100000
# 5  1001   30000

# %%
df3 = pd.merge(df1, df2) #inner join

# %%
df3
# Out:
#    고객번호   이름     금액
# 0  1001   둘리  10000
# 1  1001   둘리  20000
# 2  1001   둘리  30000
# 3  1005   희동  15000
# 4  1006  마이콜   5000

# %%
df4 = pd.merge(df1, df2, how='outer')

# %%
df4
# Out:
#    고객번호   이름        금액
# 0  1001   둘리   10000.0
# 1  1001   둘리   20000.0
# 2  1001   둘리   30000.0
# 3  1002  도우너       NaN
# 4  1003   또치       NaN
# 5  1004   길동       NaN
# 6  1005   희동   15000.0
# 7  1006  마이콜    5000.0
# 8  1007   영희       NaN
# 9  1008  NaN  100000.0

# %%
df5 = pd.merge(df1, df2, how ='left')
df5
# Out:
#    고객번호   이름       금액
# 0  1001   둘리  10000.0
# 1  1001   둘리  20000.0
# 2  1001   둘리  30000.0
# 3  1002  도우너      NaN
# 4  1003   또치      NaN
# 5  1004   길동      NaN
# 6  1005   희동  15000.0
# 7  1006  마이콜   5000.0
# 8  1007   영희      NaN

# %%
df6 = pd.merge(df1, df2, how='right')
df6
# Out:
#    고객번호   이름      금액
# 0  1001   둘리   10000
# 1  1001   둘리   20000
# 2  1001   둘리   30000
# 3  1005   희동   15000
# 4  1006  마이콜    5000
# 5  1008  NaN  100000

# %%
df1 = pd.DataFrame({
    '품종': ['setosa', 'setosa', 'virginica', 'virginica'],
    '꽃잎길이': [1.4, 1.3, 1.5, 1.3]},
    columns=['품종', '꽃잎길이'])
df1
# Out:
#           품종  꽃잎길이
# 0     setosa   1.4
# 1     setosa   1.3
# 2  virginica   1.5
# 3  virginica   1.3

# %%
df2 = pd.DataFrame({
    '품종': ['setosa', 'virginica', 'virginica', 'versicolor'],
    '꽃잎너비': [0.4, 0.3, 0.5, 0.3]},
    columns=['품종', '꽃잎너비'])
df2
# Out:
#            품종  꽃잎너비
# 0      setosa   0.4
# 1   virginica   0.3
# 2   virginica   0.5
# 3  versicolor   0.3

# %%
pd.merge(df1, df2)
# Out:
#           품종  꽃잎길이  꽃잎너비
# 0     setosa   1.4   0.4
# 1     setosa   1.3   0.4
# 2  virginica   1.5   0.3
# 3  virginica   1.5   0.5
# 4  virginica   1.3   0.3
# 5  virginica   1.3   0.5

# %%
df1 = pd.DataFrame({
    '고객명': ['춘향', '춘향', '몽룡'],
    '날짜': ['2018-01-01', '2018-01-02', '2018-01-01'],
    '데이터': ['20000', '30000', '100000']})
df1
# Out:
#   고객명          날짜     데이터
# 0  춘향  2018-01-01   20000
# 1  춘향  2018-01-02   30000
# 2  몽룡  2018-01-01  100000

# %%
df2 = pd.DataFrame({
    '고객명': ['춘향', '몽룡'],
    '데이터': ['여자', '남자']})
df2
# Out:
#   고객명 데이터
# 0  춘향  여자
# 1  몽룡  남자

# %%
pd.merge(df1, df2)
# Out:
# Empty DataFrame
# Columns: [고객명, 날짜, 데이터]
# Index: []

# %%
pd.merge(df1, df2, on = '고객명')
# Out:
#   고객명          날짜   데이터_x 데이터_y
# 0  춘향  2018-01-01   20000    여자
# 1  춘향  2018-01-02   30000    여자
# 2  몽룡  2018-01-01  100000    남자

# %%
df1 = pd.DataFrame({
    '이름': ['영희', '철수', '철수'],
    '성적': [1, 2, 3]})
df1
# Out:
#    성적  이름
# 0   1  영희
# 1   2  철수
# 2   3  철수

# %%
df2 = pd.DataFrame({
    '성명': ['영희', '영희', '철수'],
    '성적2': [4, 5, 6]})
df2
# Out:
#    성명  성적2
# 0  영희    4
# 1  영희    5
# 2  철수    6

# %%
pd.merge(df1,df2, left_on='이름', right_on='성명')
# Out:
#    성적  이름  성명  성적2
# 0   1  영희  영희    4
# 1   1  영희  영희    5
# 2   2  철수  철수    6
# 3   3  철수  철수    6

# %%
df1 = pd.DataFrame({
    '도시': ['서울', '서울', '서울', '부산', '부산'],
    '연도': [2000, 2005, 2010, 2000, 2005],
    '인구': [9853972, 9762546, 9631482, 3655437, 3512547]})
df1
# Out:
#    도시    연도       인구
# 0  서울  2000  9853972
# 1  서울  2005  9762546
# 2  서울  2010  9631482
# 3  부산  2000  3655437
# 4  부산  2005  3512547

# %%
df2 = pd.DataFrame(
    np.arange(12).reshape((6, 2)),
    index=[['부산', '부산', '서울', '서울', '서울', '서울'],
           [2000, 2005, 2000, 2005, 2010, 2015]],
    columns=['데이터1', '데이터2'])
df2
# Out:
#          데이터1  데이터2
# 부산 2000     0     1
#    2005     2     3
# 서울 2000     4     5
#    2005     6     7
#    2010     8     9
#    2015    10    11

# %%
pd.merge(df1, df2, left_on=['도시', '연도'], right_index=True)
# Out:
#    도시    연도       인구  데이터1  데이터2
# 0  서울  2000  9853972     4     5
# 1  서울  2005  9762546     6     7
# 2  서울  2010  9631482     8     9
# 3  부산  2000  3655437     0     1
# 4  부산  2005  3512547     2     3

# %%
df1 = pd.DataFrame(
    [[1., 2.], [3., 4.], [5., 6.]],
    index=['a', 'c', 'e'],
    columns=['서울', '부산'])
df1
# Out:
#     서울   부산
# a  1.0  2.0
# c  3.0  4.0
# e  5.0  6.0

# %%
df2 = pd.DataFrame(
    [[7., 8.], [9., 10.], [11., 12.], [13, 14]],
    index=['b', 'c', 'd', 'e'],
    columns=['대구', '광주'])
df2
# Out:
#      대구    광주
# b   7.0   8.0
# c   9.0  10.0
# d  11.0  12.0
# e  13.0  14.0

# %%
pd.merge(df1, df2, how='outer', left_index=True, right_index=True)
# Out:
#     서울   부산    대구    광주
# a  1.0  2.0   NaN   NaN
# b  NaN  NaN   7.0   8.0
# c  3.0  4.0   9.0  10.0
# d  NaN  NaN  11.0  12.0
# e  5.0  6.0  13.0  14.0

# %%
df1.join(df2, how='outer')
# Out:
#     서울   부산    대구    광주
# a  1.0  2.0   NaN   NaN
# b  NaN  NaN   7.0   8.0
# c  3.0  4.0   9.0  10.0
# d  NaN  NaN  11.0  12.0
# e  5.0  6.0  13.0  14.0

# %%
s1 = pd.Series([0, 1], index=['A', 'B'])
s2 = pd.Series([2, 3, 4], index=['A', 'B', 'C'])

# %%
s1
# Out:
# A    0
# B    1
# dtype: int64

# %%
s2
# Out:
# A    2
# B    3
# C    4
# dtype: int64

# %%
pd.concat([s1, s2])
# Out:
# A    0
# B    1
# A    2
# B    3
# C    4
# dtype: int64

# %%
df1 = pd.DataFrame(
    np.arange(6).reshape(3, 2), 
    index=['a', 'b', 'c'], 
    columns=['데이터1', '데이터2'])
df1
# Out:
#    데이터1  데이터2
# a     0     1
# b     2     3
# c     4     5

# %%
df2 = pd.DataFrame(
    5 + np.arange(4).reshape(2, 2),
    index=['a', 'c'],
    columns=['데이터3', '데이터4'])
df2
# Out:
#    데이터3  데이터4
# a     5     6
# c     7     8

# %%
pd.concat([df1, df2])
# Out:
#    데이터1  데이터2  데이터3  데이터4
# a   0.0   1.0   NaN   NaN
# b   2.0   3.0   NaN   NaN
# c   4.0   5.0   NaN   NaN
# a   NaN   NaN   5.0   6.0
# c   NaN   NaN   7.0   8.0

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    데이터1  데이터2  데이터3  데이터4
# a     0     1   5.0   6.0
# b     2     3   NaN   NaN
# c     4     5   7.0   8.0

# %% [markdown]
# ### 연습 문제 2¶
# - 어느 회사의 전반기(1월 ~ 6월) 실적을 나타내는 데이터프레임과 후반기(7월 ~ 12월) 실적을 나타내는 데이터프레임을 만든 뒤 합친다.
# - 실적 정보는 "매출", "비용", "이익" 으로 이루어진다. (이익 = 매출 - 비용).
#
# - 또한 1년간의 총 실적을 마지막 행으로 덧붙인다.

# %%
np.random.randint(40,90,6)
# Out:
# array([76, 67, 52, 75, 62, 60])

# %%
df_1 = pd.DataFrame(np.random.randint(40, 90, 12).reshape(6, 2),
                    index = ['1', '2', '3', '4', '5', '6'],
                   columns = ['매출', '비용'])
df_1
# Out:
#    매출  비용
# 1  87  74
# 2  46  50
# 3  55  51
# 4  60  60
# 5  43  58
# 6  89  49

# %%
df_1['이익'] = df_1['매출']-df_1['비용']

# %%
df_1
# Out:
#    매출  비용  이익
# 1  87  74  13
# 2  46  50  -4
# 3  55  51   4
# 4  60  60   0
# 5  43  58 -15
# 6  89  49  40

# %%
df_2 = pd.DataFrame(np.random.randint(40, 90, 12).reshape(6, 2),
                    index = ['7', '8', '9', '10', '11', '12'],
                   columns = ['매출', '비용'])
df_2
# Out:
#     매출  비용
# 7   45  46
# 8   81  46
# 9   60  60
# 10  89  87
# 11  62  48
# 12  76  51

# %%
df_2['이익'] = df_2['매출'] - df_2['비용']
df_2
# Out:
#     매출  비용  이익
# 7   45  46  -1
# 8   81  46  35
# 9   60  60   0
# 10  89  87   2
# 11  62  48  14
# 12  76  51  25

# %%
df_12 = pd.concat([df_1, df_2], axis=0)

# %%
df_12
# Out:
#     매출  비용  이익
# 1   87  74  13
# 2   46  50  -4
# 3   55  51   4
# 4   60  60   0
# 5   43  58 -15
# 6   89  49  40
# 7   45  46  -1
# 8   81  46  35
# 9   60  60   0
# 10  89  87   2
# 11  62  48  14
# 12  76  51  25

# %%
df_12.sum()
# Out:
# 매출    793
# 비용    680
# 이익    113
# dtype: int64

# %%
df_12.loc['1년실적'] = df_12.sum()

# %%
df_12
# Out:
#        매출   비용   이익
# 1      87   74   13
# 2      46   50   -4
# 3      55   51    4
# 4      60   60    0
# 5      43   58  -15
# 6      89   49   40
# 7      45   46   -1
# 8      81   46   35
# 9      60   60    0
# 10     89   87    2
# 11     62   48   14
# 12     76   51   25
# 1년실적  793  680  113

# %%
data = {
    "도시": [
        "서울", "서울", "서울", "부산", "부산", "부산", "인천", "인천"
    ],
    "연도": [
        "2015", "2010", "2005", "2015", "2010", "2005", "2015", "2010"
    ],
    "인구": [
        9904312, 9631482, 9762546, 3448737, 3393191, 3512547, 2890451, 2632035
    ],
    "지역": [
        "수도권", "수도권", "수도권", "경상권", "경상권", "경상권", "수도권", "수도권"
    ]
}
columns = ["도시", "연도", "인구", "지역"]
df1 = pd.DataFrame(data, columns=columns)
df1
# Out:
#    도시    연도       인구   지역
# 0  서울  2015  9904312  수도권
# 1  서울  2010  9631482  수도권
# 2  서울  2005  9762546  수도권
# 3  부산  2015  3448737  경상권
# 4  부산  2010  3393191  경상권
# 5  부산  2005  3512547  경상권
# 6  인천  2015  2890451  수도권
# 7  인천  2010  2632035  수도권

# %%
df1.pivot("도시", "연도", "인구")
# Out:
# 연도       2005       2010       2015
# 도시
# 부산  3512547.0  3393191.0  3448737.0
# 서울  9762546.0  9631482.0  9904312.0
# 인천        NaN  2632035.0  2890451.0

# %%
df1.set_index(["도시", "연도"])[["인구"]].unstack()
# Out:
#            인구
# 연도       2005       2010       2015
# 도시
# 부산  3512547.0  3393191.0  3448737.0
# 서울  9762546.0  9631482.0  9904312.0
# 인천        NaN  2632035.0  2890451.0

# %%
np.random.seed(0)
df2 = pd.DataFrame({
    'key1': ['A', 'A', 'B', 'B', 'A'],
    'key2': ['one', 'two', 'one', 'two', 'one'],
    'data1': [1, 2, 3, 4, 5],
    'data2': [10, 20, 30, 40, 50]
})
df2
# Out:
#    data1  data2 key1 key2
# 0      1     10    A  one
# 1      2     20    A  two
# 2      3     30    B  one
# 3      4     40    B  two
# 4      5     50    A  one

# %%
df2.groupby(df2.key1).sum()
# Out:
#       data1  data2
# key1
# A         8     80
# B         7     70

# %%
df2.data1.groupby(df2.key1).sum()
# Out:
# key1
# A    8
# B    7
# Name: data1, dtype: int64

# %%
df2.groupby(df2.key1)['data1'].sum()
# Out:
# key1
# A    8
# B    7
# Name: data1, dtype: int64

# %% [markdown]
# ### 연습 문제 1¶
# - key 1의 값을 기준으로 data1의 값을 분류하여 합계를 구한 결과를 시리즈가 아닌 데이터프레임으로 구한다.

# %%
df2.groupby(df2.key1).sum()[['data1']]
# Out:
#       data1
# key1
# A         8
# B         7

# %%
df
# Out:
#       data1  data2
# key1
# A         8     80
# B         7     70

# %%
df[['data1']]
# Out:
#       data1
# key1
# A         8
# B         7

# %%
df2.data1.groupby([df2.key1, df2.key2]).sum()
# Out:
# key1  key2
# A     one     6
#       two     2
# B     one     3
#       two     4
# Name: data1, dtype: int64

# %%
df2.data1.groupby([df2["key1"], df2["key2"]]).sum().unstack("key2")
# Out:
# key2  one  two
# key1
# A       6    2
# B       3    4

# %%
df1["인구"].groupby([df1["지역"], df1["연도"]]).sum().unstack("연도")
# Out:
# 연도      2005      2010      2015
# 지역
# 경상권  3512547   3393191   3448737
# 수도권  9762546  12263517  12794763

# %%
import seaborn as sns
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
def peak_to_peak_ratio(x) :
    return x.max() / x.min()

# %%
iris.groupby(iris.species).agg(peak_to_peak_ratio)
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa          1.348837     1.913043      1.900000     6.000000
# versicolor      1.428571     1.700000      1.700000     1.800000
# virginica       1.612245     1.727273      1.533333     1.785714

# %%
iris.groupby(iris.species).describe().T
# Out:
# species                setosa  versicolor  virginica
# petal_length count  50.000000   50.000000  50.000000
#              mean    1.462000    4.260000   5.552000
#              std     0.173664    0.469911   0.551895
#              min     1.000000    3.000000   4.500000
#              25%     1.400000    4.000000   5.100000
#              50%     1.500000    4.350000   5.550000
#              75%     1.575000    4.600000   5.875000
#              max     1.900000    5.100000   6.900000
# petal_width  count  50.000000   50.000000  50.000000
#              mean    0.246000    1.326000   2.026000
#              std     0.105386    0.197753   0.274650
#              min     0.100000    1.000000   1.400000
#              25%     0.200000    1.200000   1.800000
#              50%     0.200000    1.300000   2.000000
#              75%     0.300000    1.500000   2.300000
#              max     0.600000    1.800000   2.500000
# sepal_length count  50.000000   50.000000  50.000000
# ...

# %%
def max_3(df) :
    return df.sort_values(by='petal_length')[:3]

# %%
iris.groupby(iris.species).apply(max_3)
# Out:
#                 sepal_length  sepal_width  petal_length  petal_width  \
# species
# setosa     22            4.6          3.6           1.0          0.2
#            13            4.3          3.0           1.1          0.1
#            14            5.8          4.0           1.2          0.2
# versicolor 98            5.1          2.5           3.0          1.1
#            93            5.0          2.3           3.3          1.0
#            57            4.9          2.4           3.3          1.0
# virginica  106           4.9          2.5           4.5          1.7
#            126           6.2          2.8           4.8          1.8
#            138           6.0          3.0           4.8          1.8
#
#                    species
# species
# setosa     22       setosa
#            13       setosa
#            14       setosa
# versicolor 98   versicolor
#            93   versicolor
#            57   versicolor
# virginica  106   virginica
#            126   virginica
# ...

# %%
def q3cut(s) :
    return pd.qcut(s, 3, labels = ['소', '중', '대'])

# %%
iris['petal_length_class'] = iris.groupby(iris.species)['petal_length'].transform(q3cut)
iris[['petal_length', 'petal_length_class']].tail(10)
# Out:
#      petal_length petal_length_class
# 140           5.6                  중
# 141           5.1                  소
# 142           5.1                  소
# 143           5.9                  대
# 144           5.7                  중
# 145           5.2                  소
# 146           5.0                  소
# 147           5.2                  소
# 148           5.4                  중
# 149           5.1                  소

# %% [markdown]
# ### 연습 문제 2¶
# - 붓꽃(iris) 데이터에서 붓꽃 종(species)별로 꽃잎길이(sepal_length), 꽃잎폭(sepal_width) 등의 평균을 구하라. 만약 붓꽃 종(species)이 표시되지 않았을 때 이 수치들을 이용하여 붓꽃 종을 찾아낼 수 있을지 생각하라.

# %%
iris.groupby(iris.species)[['sepal_length', 'sepal_width']].mean()
# Out:
#             sepal_length  sepal_width
# species
# setosa             5.006        3.428
# versicolor         5.936        2.770
# virginica          6.588        2.974

# %%
df2.pivot_table("data1", "key1", "key2")
# Out:
# key2  one  two
# key1
# A       3    2
# B       3    4

# %%
df2.pivot_table("data1", "key1", "key2", margins=True, margins_name="합계")
# Out:
# key2  one  two        합계
# key1
# A       3    2  2.666667
# B       3    4  3.500000
# 합계      3    3  3.000000

# %%
#aggfunc default = mean
df2.pivot_table("data1", index=["key1", "key2"], aggfunc=[np.sum], margins=True, margins_name='합계')
# Out:
#             sum
#           data1
# key1 key2
# A    one      6
#      two      2
# B    one      3
#      two      4
# 합계           15

# %%
tips = sns.load_dataset("tips")
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips['tip_pct'] = tips['tip']/tips['total_bill']
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.159744

# %%
tips.describe()
# Out:
#        total_bill         tip        size     tip_pct
# count  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672    0.160803
# std      8.902412    1.383638    0.951100    0.061072
# min      3.070000    1.000000    1.000000    0.035638
# 25%     13.347500    2.000000    2.000000    0.129127
# 50%     17.795000    2.900000    2.000000    0.154770
# 75%     24.127500    3.562500    3.000000    0.191475
# max     50.810000   10.000000    6.000000    0.710345

# %%
tips.groupby('sex').count()
# Out:
#         total_bill  tip  smoker  day  time  size  tip_pct
# sex
# Male           157  157     157  157   157   157      157
# Female          87   87      87   87    87    87       87

# %%
tips.groupby('sex').size()
# Out:
# sex
# Male      157
# Female     87
# dtype: int64

# %%
tips.groupby(['sex', 'smoker']).size()
# Out:
# sex     smoker
# Male    Yes       60
#         No        97
# Female  Yes       33
#         No        54
# dtype: int64

# %%
tips.pivot_table('tip_pct', 'sex', 'smoker', aggfunc='count', margins=True)
# Out:
# smoker  Yes   No  All
# sex
# Male     60   97  157
# Female   33   54   87
# All      93  151  244

# %%
tips.groupby('sex')[['tip_pct']].mean()
# Out:
#          tip_pct
# sex
# Male    0.157651
# Female  0.166491

# %%
tips.groupby('smoker')[['tip_pct']].mean()
# Out:
#          tip_pct
# smoker
# Yes     0.163196
# No      0.159328

# %%
tips.pivot_table('tip_pct',['sex', 'smoker'])
# Out:
#                 tip_pct
# sex    smoker
# Male   Yes     0.152771
#        No      0.160669
# Female Yes     0.182150
#        No      0.156921

# %%
tips.groupby('sex')['tip_pct'].describe()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# sex
# Male    157.0  0.157651  0.064778  0.035638  0.121389  0.153492  0.186240
# Female   87.0  0.166491  0.053632  0.056433  0.140416  0.155581  0.194266
#
#              max
# sex
# Male    0.710345
# Female  0.416667

# %%
tips.groupby("smoker")[["tip_pct"]].describe()
# Out:
#        tip_pct                                                              \
#          count      mean       std       min       25%       50%       75%
# smoker
# Yes       93.0  0.163196  0.085119  0.035638  0.106771  0.153846  0.195059
# No       151.0  0.159328  0.039910  0.056797  0.136906  0.155625  0.185014
#
#
#              max
# smoker
# Yes     0.710345
# No      0.291990

# %%
tips.groupby(["sex", "smoker"])[["tip_pct"]].describe()
# Out:
#               tip_pct                                                    \
#                 count      mean       std       min       25%       50%
# sex    smoker
# Male   Yes       60.0  0.152771  0.090588  0.035638  0.101845  0.141015
#        No        97.0  0.160669  0.041849  0.071804  0.131810  0.157604
# Female Yes       33.0  0.182150  0.071595  0.056433  0.152439  0.173913
#        No        54.0  0.156921  0.036421  0.056797  0.139708  0.149691
#
#
#                     75%       max
# sex    smoker
# Male   Yes     0.191697  0.710345
#        No      0.186220  0.291990
# Female Yes     0.198216  0.416667
#        No      0.181630  0.252672

# %% [markdown]
# ### 연습 문제 3¶
# - 팁의 비율이 요일과 점심/저녁 여부, 인원수에 어떤 영향을 받는지 살펴본다.
# - 어떤 요인이 가장 크게 작용하는지 판단할 수 있는 방법이 있는가?

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.159744

# %%
tips.groupby(['day'])['tip_pct'].describe()
# Out:
#       count      mean       std       min       25%       50%       75%  \
# day
# Thur   62.0  0.161276  0.038652  0.072961  0.138210  0.153846  0.192687
# Fri    19.0  0.169913  0.047665  0.103555  0.133739  0.155625  0.196637
# Sat    87.0  0.153152  0.051293  0.035638  0.123863  0.151832  0.188271
# Sun    76.0  0.166897  0.084739  0.059447  0.119982  0.161103  0.187889
#
#            max
# day
# Thur  0.266312
# Fri   0.263480
# Sat   0.325733
# Sun   0.710345

# %%
tips.groupby(['time'])['tip_pct'].describe()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# time
# Lunch    68.0  0.164128  0.040242  0.072961  0.139147  0.154084  0.193917
# Dinner  176.0  0.159518  0.067477  0.035638  0.123192  0.155400  0.188209
#
#              max
# time
# Lunch   0.266312
# Dinner  0.710345

# %%
tips.groupby(['day'])['tip_pct'].describe()
# Out:
#       count      mean       std       min       25%       50%       75%  \
# day
# Thur   62.0  0.161276  0.038652  0.072961  0.138210  0.153846  0.192687
# Fri    19.0  0.169913  0.047665  0.103555  0.133739  0.155625  0.196637
# Sat    87.0  0.153152  0.051293  0.035638  0.123863  0.151832  0.188271
# Sun    76.0  0.166897  0.084739  0.059447  0.119982  0.161103  0.187889
#
#            max
# day
# Thur  0.266312
# Fri   0.263480
# Sat   0.325733
# Sun   0.710345

# %%
def peak_to_peak(x):
    return x.max() - x.min()

tips.groupby(["sex", "smoker"])[["tip"]].agg(peak_to_peak)
# Out:
#                 tip
# sex    smoker
# Male   Yes     9.00
#        No      7.75
# Female Yes     5.50
#        No      4.20

# %%
tips.groupby(["sex", "smoker"]).agg(["mean", peak_to_peak])[["total_bill"]]
# Out:
#               total_bill
#                     mean peak_to_peak
# sex    smoker
# Male   Yes     22.284500        43.56
#        No      19.791237        40.82
# Female Yes     17.977879        41.23
#        No      18.105185        28.58

# %%
tips.groupby(["sex", "smoker"]).agg({'tip_pct' : 'mean', 'total_bill' : peak_to_peak})
# Out:
#                 tip_pct  total_bill
# sex    smoker
# Male   Yes     0.152771       43.56
#        No      0.160669       40.82
# Female Yes     0.182150       41.23
#        No      0.156921       28.58

# %%
tips.pivot_table(['tip_pct', 'size'], ['sex', 'day'], 'smoker')
# Out:
#                  size             tip_pct
# smoker            Yes        No       Yes        No
# sex    day
# Male   Thur  2.300000  2.500000  0.164417  0.165706
#        Fri   2.125000  2.000000  0.144730  0.138005
#        Sat   2.629630  2.656250  0.139067  0.162132
#        Sun   2.600000  2.883721  0.173964  0.158291
# Female Thur  2.428571  2.480000  0.163073  0.155971
#        Fri   2.000000  2.500000  0.209129  0.165296
#        Sat   2.200000  2.307692  0.163817  0.147993
#        Sun   2.500000  3.071429  0.237075  0.165710

# %%
tips.pivot_table('size', ['time', 'sex', 'smoker'], 'day', 
                 aggfunc='sum', fill_value=0)
# Out:
# day                   Thur  Fri  Sat  Sun
# time   sex    smoker
# Lunch  Male   Yes       23    5    0    0
#               No        50    0    0    0
#        Female Yes       17    6    0    0
#               No        60    3    0    0
# Dinner Male   Yes        0   12   71   39
#               No         0    4   85  124
#        Female Yes        0    8   33   10
#               No         2    2   30   43

# %% [markdown]
# ### 연습 문제 4¶
# 타이타닉 승객 데이터를 이용하여 다음 분석을 실시하라. 데이터는 다음과 같이 받을 수 있다.
#
# `titanic = sns.load_dataset("titanic")`
# - qcut 명령으로 세 개의 나이 그룹을 만든다.
# - 성별, 선실, 나이 그룹에 의한 생존율을 데이터프레임으로 계산한다. 행에는 성별 및 나이 그룹에 대한 다중 인덱스를 사용하고 열에는 선실 인덱스를 사용한다.
# - 성별 및 선실에 의한 생존율을 피봇 데이터 형태로 만든다.

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
def q3cut(s) :
    return pd.qcut(s, 3, labels = ['young', 'middle', 'old'])

# %%
titanic['age_class'] = titanic.groupby(titanic['class'])['age'].transform(q3cut)
titanic[['age', 'age_class']].tail()
# Out:
#       age age_class
# 886  27.0    middle
# 887  19.0     young
# 888   NaN       NaN
# 889  26.0     young
# 890  32.0       old

# %%
titanic.alive.size
# Out:
# 891

# %%
def alive_ratio(x):
    return x.count() / titanic.alive.size

# %%
titanic['alive_ratio'] = titanic['alive'] / titanic[]

# %%
#df2.data1.groupby([df2["key1"], df2["key2"]]).sum().unstack("key2")

# %%
#생존율
titanic.groupby(['age_class', 'sex', 'class'])[['alive']].agg(alive_ratio).unstack()
# Out:
#                      alive
# class                First    Second     Third
# age_class sex
# young     female  0.041526  0.030303  0.052750
#           male    0.032548  0.034792  0.085297
# middle    female  0.031425  0.029181  0.032548
#           male    0.033670  0.040404  0.099888
# old       female  0.022447  0.023569  0.029181
#           male    0.047138  0.035915  0.098765

# %%
titanic.groupby([ 'sex', 'class'])[['alive']].agg(alive_ratio).unstack()
# Out:
#            alive
# class      First    Second     Third
# sex
# female  0.105499  0.085297  0.161616
# male    0.136925  0.121212  0.389450
