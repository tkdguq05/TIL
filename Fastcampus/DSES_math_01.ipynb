# %%
from scipy import stats

p = 0.6
bernoulli_dist = stats.bernoulli(p)

# %%
p_tail = bernoulli_dist.pmf(0)
p_head = bernoulli_dist.pmf(1)

# %%
print('Prob of tail:', p_tail)
print('Prob of head:', p_head)
# Out:
# Prob of tail: 0.4
# Prob of head: 0.6

# %%
trials = bernoulli_dist.rvs(10) # 베르누이 분포를 따르는 10개의 샘플
trials
# Out:
# array([1, 1, 0, 1, 1, 0, 0, 1, 0, 0])

# %% [markdown]
# ## Binomial Dist

# %%
n = 10  # 주사위를 10번 던진다.
p = 1/6  # 3의 눈이 나올 확률 1/6

binom_dist = stats.binom(n, p)

# %%
import numpy as np

# 3의 눈이 1번, 2번, 3번, ..., 10번 나올 확률
trials = binom_dist.pmf(np.arange(10))
trials
# Out:
# array([1.61505583e-01, 3.23011166e-01, 2.90710049e-01, 1.55045360e-01,
#        5.42658759e-02, 1.30238102e-02, 2.17063503e-03, 2.48072575e-04,
#        1.86054431e-05, 8.26908584e-07])

# %%
# Float formatting 변경
[round(x, 5) for x in trials]
# Out:
# [0.16151,
#  0.32301,
#  0.29071,
#  0.15505,
#  0.05427,
#  0.01302,
#  0.00217,
#  0.00025,
#  2e-05,
#  0.0]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.5)
# Out:
# /Users/sanghyub/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/sanghyub/anaconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
binom_dist1 = stats.binom(20, 0.5)
binom_dist2 = stats.binom(20, 0.7)
binom_dist3 = stats.binom(40, 0.5)

k = np.arange(40)
plt.plot(k, binom_dist1.pmf(k), 'o-b')
plt.plot(k, binom_dist2.pmf(k), 'd-r')
plt.plot(k, binom_dist3.pmf(k), 's-g')
plt.title('Binomial Distribution')
plt.legend(['p=0/5 and n=20', 'p=0.7 and n=20', 'p=0.5 and n = 40'])
plt.xlabel('X')
plt.ylabel('P(X)')
# Out:
# Text(0,0.5,'P(X)')

# %% [markdown]
# ## Poisson Dist

# %%
poisson_dist1 = stats.poisson(5) # lambda 값
n = np.arange(50)

plt.plot(n, poisson_dist1.pmf(n), 'o-b')
plt.legend(['$\lambda$=5'])
plt.xlabel('X')
plt.ylabel('P(X)')
# Out:
# Text(0,0.5,'P(X)')

# %% [markdown]
# ## Normal Dist
